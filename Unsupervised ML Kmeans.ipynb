# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs
x,y=make_blobs(n_samples=500,n_features=2,centers=4,cluster_std=1,random_state=1)
plt.scatter(x[:,0],x[:,1],c=y)

# %%
from sklearn.cluster import KMeans
model=KMeans(n_clusters=2)
model.fit(x)
centers=model.cluster_centers_
plt.scatter(x[:,0],x[:,1],c=y)
plt.scatter(centers[:,0],centers[:,1],c="black")

# %%
import pandas as pd
data=pd.read_excel("zscoreddata.xls")
model=KMeans(n_clusters=3)
model.fit(data)
model.cluster_centers_
# Out:
# array([[-0.28255892,  1.49677344, -0.55832197, -0.52215415, -0.03798459],
#        [ 0.0171507 , -0.45123989, -0.15463441, -0.15893633, -0.04953123],
#        [ 0.54982483, -0.77834083,  2.20284596,  2.14494308,  0.38088687]])
